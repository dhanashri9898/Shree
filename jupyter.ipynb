# %% [markdown]
# <a href="https://colab.research.google.com/github/dhanashri9898/Shree/blob/main/jupyter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
A=(input("length of string"))
print(A)
a=input("enter first string")
b=input("enter second string")
c=a+b
print(c)
A="shree"
B="patil"
C=A+B
print(C)
# Out:
# length of string4
# 4
# enter first string2
# enter second string2
# 22
# shreepatil
